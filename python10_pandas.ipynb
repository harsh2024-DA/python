# %%
import pandas as pd

# %%
import seaborn as sns

# %%
titanic_data = sns.load_dataset('titanic')

# %%
df = titanic_data

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df[['class', 'sex', 'age']]    #nested list
# Out:
#       class     sex   age
# 0     Third    male  22.0
# 1     First  female  38.0
# 2     Third  female  26.0
# 3     First  female  35.0
# 4     Third    male  35.0
# ..      ...     ...   ...
# 886  Second    male  27.0
# 887   First  female  19.0
# 888   Third  female   NaN
# 889   First    male  26.0
# 890   Third    male  32.0
#
# [891 rows x 3 columns]

# %%
df1 = df[df['sex'] =='male']

# %%
df1.head()
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  male  22.0      1      0   7.2500        S  Third    man
# 4         0       3  male  35.0      0      0   8.0500        S  Third    man
# 5         0       3  male   NaN      0      0   8.4583        Q  Third    man
# 6         0       1  male  54.0      0      0  51.8625        S  First    man
# 7         0       3  male   2.0      3      1  21.0750        S  Third  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 4        True  NaN  Southampton    no   True
# 5        True  NaN   Queenstown    no   True
# 6        True    E  Southampton    no   True
# 7       False  NaN  Southampton    no  False

# %%
df2 = df[ (df['sex'] =='male')  & (df['class']=='First') ]

# %%
df2.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch      fare embarked  class  who  \
# 6          0       1  male  54.0      0      0   51.8625        S  First  man
# 23         1       1  male  28.0      0      0   35.5000        S  First  man
# 27         0       1  male  19.0      3      2  263.0000        S  First  man
# 30         0       1  male  40.0      0      0   27.7208        C  First  man
# 34         0       1  male  28.0      1      0   82.1708        C  First  man
#
#     adult_male deck  embark_town alive  alone
# 6         True    E  Southampton    no   True
# 23        True    A  Southampton   yes   True
# 27        True    C  Southampton    no  False
# 30        True  NaN    Cherbourg    no   True
# 34        True  NaN    Cherbourg    no  False

# %%
#need dataset for age =[ 20, 21 , or 22]

# %%
age = [20, 21, 22]

# %%
df[df['age'].isin(age)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 37          0       3    male  21.0      0      0   8.0500        S   Third
# 51          0       3    male  21.0      0      0   7.8000        S   Third
# 56          1       2  female  21.0      0      0  10.5000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 836         0       3    male  21.0      0      0   8.6625        S   Third
# 840         0       3    male  20.0      0      0   7.9250        S   Third
# 861         0       2    male  21.0      1      0  11.5000        S  Second
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#indexing & slicing

# %%
scores = [
 {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B', 'Remarks': 'Good', },
 {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks': 'Exce lent'},
 {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks': 'Exce lent'},
 ]
my_df = pd.DataFrame(scores)
my_df.head()
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Exce lent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Exce lent

# %%
my_df.loc[2]
# Out:
# Subject    English
# Score           76
# Grade            C
# Remarks       Fair
# Name: 2, dtype: object

# %%
df = pd.DataFrame(scores, index = ['row1', 'row2', 'row3', 'row4', 'row5'])

# %%
df
# Out:
#           Subject  Score Grade    Remarks
# row1  Mathematics     85     B       Good
# row2      History     98     A  Exce lent
# row3      English     76     C       Fair
# row4      Science     72     C       Fair
# row5         Arts     95     A  Exce lent

# %%
df.loc['row2']   #location - index name pass
# Out:
# Subject      History
# Score             98
# Grade              A
# Remarks    Exce lent
# Name: row2, dtype: object

# %%
df.iloc[2] #index location
# Out:
# Subject    English
# Score           76
# Grade            C
# Remarks       Fair
# Name: row3, dtype: object

# %%
df.iloc[2:4]
# Out:
#       Subject  Score Grade Remarks
# row3  English     76     C    Fair
# row4  Science     72     C    Fair

# %%
df.loc[['row1','row3'], ['Grade', 'Score']]
# Out:
#      Grade  Score
# row1     B     85
# row3     C     76

# %% [markdown]
# #dropping rows and columns with drop()

# %%
 scores = [
 {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B', 'Remarks': 'Good', },
 {'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks': 'Exce lent'},
{'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Science', 'Score': 72 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Arts', 'Score': 95 , 'Grade': 'A','Remarks': 'Exce lent'},
 ]

# %%
df = pd.DataFrame(scores)

# %%
df
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Exce lent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Exce lent

# %%
df1 = df

# %%
df1.drop([1,4])
# Out:
#        Subject  Score Grade Remarks
# 0  Mathematics     85     B    Good
# 2      English     76     C    Fair
# 3      Science     72     C    Fair

# %%
df1.drop('Subject', axis =1)
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df1
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Exce lent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Exce lent

# %%
#  inplace for permenetn deletation or drop

# %%
df.drop('Subject', axis =1, inplace= True)   #True is use for permanant. by default Flase

# %%
df
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df1
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df1.head()
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df.head()
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df2 = pd.DataFrame(scores)

# %%
df2
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Exce lent
# 2      English     76     C       Fair
# 3      Science     72     C       Fair
# 4         Arts     95     A  Exce lent

# %%
df
# Out:
#    Score Grade    Remarks
# 0     85     B       Good
# 1     98     A  Exce lent
# 2     76     C       Fair
# 3     72     C       Fair
# 4     95     A  Exce lent

# %%
df['SUBJECT'] = df2['Subject']

# %%
df
# Out:
#    Score Grade    Remarks      SUBJECT
# 0     85     B       Good  Mathematics
# 1     98     A  Exce lent      History
# 2     76     C       Fair      English
# 3     72     C       Fair      Science
# 4     95     A  Exce lent         Arts

# %%
df.filter([1 ,3 ,4], axis=0)
# Out:
#    Score Grade    Remarks  SUBJECT
# 1     98     A  Exce lent  History
# 3     72     C       Fair  Science
# 4     95     A  Exce lent     Arts

# %%
df5 =df.filter([1 ,3 ,4], axis=0)

# %%
df5
# Out:
#    Score Grade    Remarks  SUBJECT
# 1     98     A  Exce lent  History
# 3     72     C       Fair  Science
# 4     95     A  Exce lent     Arts

# %%
df5 = df5.reset_index()

# %%
df5
# Out:
#    index  Score Grade    Remarks  SUBJECT
# 0      1     98     A  Exce lent  History
# 1      3     72     C       Fair  Science
# 2      4     95     A  Exce lent     Arts

# %%
df5 = df5.drop('index', axis =1)

# %%
df5
# Out:
#    Score Grade    Remarks  SUBJECT
# 0     98     A  Exce lent  History
# 1     72     C       Fair  Science
# 2     95     A  Exce lent     Arts

# %%
dft = sns.load_dataset('titanic')

# %%
dft.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_Age = dft.sort_values(by =['age'])

# %%
df_Age.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %%
df_Age =df_Age.reset_index(drop =True)

# %%
df_Age.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       3    male  0.42      0      1   8.5167        C   Third
# 1         1       2    male  0.67      1      1  14.5000        S  Second
# 2         1       3  female  0.75      2      1  19.2583        C   Third
# 3         1       3  female  0.75      2      1  19.2583        C   Third
# 4         1       2    male  0.83      0      2  29.0000        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0  child       False  NaN    Cherbourg   yes  False
# 1  child       False  NaN  Southampton   yes  False
# 2  child       False  NaN    Cherbourg   yes  False
# 3  child       False  NaN    Cherbourg   yes  False
# 4  child       False  NaN  Southampton   yes  False

# %%
dft.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #unique

# %%
dft['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
dft['class'].nunique()
# Out:
# 3

# %%
dft.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
dft.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dft['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
dft['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %% [markdown]
# #Data Grouping, Aggregation, and Merging with
#  Pandas

# %%
dft.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dft2 = dft.groupby('class')
# Out:
# <ipython-input-90-32a39de5f1a1>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dft2 = dft.groupby('class')

# %%
dft2

# %%
dft2.ngroups
# Out:
# 3

# %%
dft2.size()
# Out:
# class
# First     216
# Second    184
# Third     491
# dtype: int64

# %%
dft2.groups['First']
# Out:
# Index([  1,   3,   6,  11,  23,  27,  30,  31,  34,  35,
#        ...
#        853, 856, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=216)

# %%
dft2.first()
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked    who  \
# class
# First          1       1  female  38.0      1      0  71.2833        C  woman
# Second         1       2  female  14.0      1      0  30.0708        C  child
# Third          0       3    male  22.0      1      0   7.2500        S    man
#
#         adult_male deck  embark_town alive  alone
# class
# First        False    C    Cherbourg   yes  False
# Second       False    D    Cherbourg   yes  False
# Third         True    G  Southampton    no  False

# %%
dft2.last()
# Out:
#         survived  pclass   sex   age  sibsp  parch   fare embarked  who  \
# class
# First          1       1  male  26.0      0      0  30.00        C  man
# Second         0       2  male  27.0      0      0  13.00        S  man
# Third          0       3  male  32.0      0      0   7.75        Q  man
#
#         adult_male deck  embark_town alive  alone
# class
# First         True    C    Cherbourg   yes   True
# Second        True    E  Southampton    no   True
# Third         True    E   Queenstown    no   True

# %%
dft2.age.max()
# Out:
# class
# First     80.0
# Second    70.0
# Third     74.0
# Name: age, dtype: float64

# %%
# i need mx, min, count, median and mean of fare column by class wise

dft2.fare.agg(['max', 'min', 'count', 'median', 'mean'])
# Out:
#              max  min  count   median       mean
# class
# First   512.3292  0.0    216  60.2875  84.154687
# Second   73.5000  0.0    184  14.2500  20.662183
# Third    69.5500  0.0    491   8.0500  13.675550

# %%
scores1 = [
 {'Subject':'Mathematics', 'Score': 85 , 'Grade': 'B', 'Remarks': 'Good', },
{'Subject':'History', 'Score': 98 , 'Grade': 'A','Remarks': 'Excellent'},
 {'Subject':'English', 'Score': 76 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Chemistry', 'Score': 72 , 'Grade': 'C','Remarks': 'Fair'},
 ]

scores2 = [
 {'Subject':'Arts', 'Score': 70 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'Physics', 'Score': 75 , 'Grade': 'C','Remarks': 'Fair'},
 {'Subject':'English', 'Score': 92 , 'Grade': 'A','Remarks': 'Excellent'},
 {'Subject':'Chemistry', 'Score': 91 , 'Grade': 'A','Remarks': 'Excellent'},
 ]

# %%
dfs1 = pd.DataFrame(scores1)

dfs2 = pd.DataFrame(scores2)

# %%
dfs1
# Out:
#        Subject  Score Grade    Remarks
# 0  Mathematics     85     B       Good
# 1      History     98     A  Excellent
# 2      English     76     C       Fair
# 3    Chemistry     72     C       Fair

# %%
dfs2
# Out:
#      Subject  Score Grade    Remarks
# 0       Arts     70     C       Fair
# 1    Physics     75     C       Fair
# 2    English     92     A  Excellent
# 3  Chemistry     91     A  Excellent

# %%
df_new_inner =dfs1.merge(dfs2, on ='Subject', how ='inner' )

# %%
df_new_inner
# Out:
#      Subject  Score_x Grade_x Remarks_x  Score_y Grade_y  Remarks_y
# 0    English       76       C      Fair       92       A  Excellent
# 1  Chemistry       72       C      Fair       91       A  Excellent

# %%
df_new_outer =dfs1.merge(dfs2, on ='Subject', how ='outer' )

# %%
df_new_outer
# Out:
#        Subject  Score_x Grade_x  Remarks_x  Score_y Grade_y  Remarks_y
# 0         Arts      NaN     NaN        NaN     70.0       C       Fair
# 1    Chemistry     72.0       C       Fair     91.0       A  Excellent
# 2      English     76.0       C       Fair     92.0       A  Excellent
# 3      History     98.0       A  Excellent      NaN     NaN        NaN
# 4  Mathematics     85.0       B       Good      NaN     NaN        NaN
# 5      Physics      NaN     NaN        NaN     75.0       C       Fair

# %%
df_new_outer =dfs1.merge(dfs2, on ='Subject', how ='right' )
df_new_outer
# Out:
#      Subject  Score_x Grade_x Remarks_x  Score_y Grade_y  Remarks_y
# 0       Arts      NaN     NaN       NaN       70       C       Fair
# 1    Physics      NaN     NaN       NaN       75       C       Fair
# 2    English     76.0       C      Fair       92       A  Excellent
# 3  Chemistry     72.0       C      Fair       91       A  Excellent

# %%
df_new_outer =dfs1.merge(dfs2, on ='Subject', how ='left' )
df_new_outer
# Out:
#        Subject  Score_x Grade_x  Remarks_x  Score_y Grade_y  Remarks_y
# 0  Mathematics       85       B       Good      NaN     NaN        NaN
# 1      History       98       A  Excellent      NaN     NaN        NaN
# 2      English       76       C       Fair     92.0       A  Excellent
# 3    Chemistry       72       C       Fair     91.0       A  Excellent

# %%
dft.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dft['age'].hist()
# Out:
# <Axes: >
